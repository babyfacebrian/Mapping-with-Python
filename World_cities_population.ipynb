# %%
import folium
import pandas as pd
import json

# %%
data = pd.read_csv('/Users/briankalinowski/projects/mapping/worldcitiespop.csv')
# Out:
# //anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#   Country        City  AccentCity Region  Population   Latitude  Longitude
# 0      ad       aixas       Aix�s      6         NaN  42.483333   1.466667
# 1      ad  aixirivali  Aixirivali      6         NaN  42.466667   1.500000
# 2      ad  aixirivall  Aixirivall      6         NaN  42.466667   1.500000
# 3      ad   aixirvall   Aixirvall      6         NaN  42.466667   1.500000
# 4      ad    aixovall    Aixovall      6         NaN  42.466667   1.483333

# %%
data.shape
# Out:
# (3173958, 7)

# %%
pop_data = data.dropna()

# %%
pop_data.head()
# Out:
#    Country              City        AccentCity Region  Population   Latitude  \
# 6       ad  andorra la vella  Andorra la Vella      7     20430.0  42.500000
# 20      ad           canillo           Canillo      2      3292.0  42.566667
# 32      ad            encamp            Encamp      3     11224.0  42.533333
# 49      ad        la massana        La Massana      4      7211.0  42.550000
# 53      ad      les escaldes      Les Escaldes      8     15854.0  42.500000
#
#     Longitude
# 6    1.516667
# 20   1.600000
# 32   1.583333
# 49   1.516667
# 53   1.533333

# %%
pop_data.Longitude.min()
# Out:
# -179.5

# %%
pop_data.Longitude.max()
# Out:
# 179.316667

# %%
pop_data.shape
# Out:
# (47979, 7)

# %%
pop_data.Country.value_counts()[0:25]
# Out:
# ru    4324
# us    4175
# ph    3752
# in    2995
# ro    2755
# br    2017
# mx    1687
# de    1478
# it    1118
# gr    1084
# co    1036
# fr     863
# gb     861
# hu     836
# ua     826
# jp     755
# cn     748
# ca     721
# cz     618
# no     577
# hn     509
# be     503
# es     488
# pt     427
# pl     426
# Name: Country, dtype: int64

# %%
pop_data.Region.value_counts()[0:25]
# Out:
# 2.0     1129
# 8.0      945
# 16.0     914
# 1.0      897
# 7.0      880
# 5.0      870
# 4.0      858
# 02       846
# 04       779
# 9.0      776
# 15.0     771
# 01       748
# 6.0      681
# 03       677
# 10.0     648
# 13.0     641
# 05       631
# 00       621
# 3.0      603
# 36.0     601
# 11.0     588
# 12.0     550
# 06       535
# 07       535
# 08       526
# Name: Region, dtype: int64

# %%
pop_data.Population.min()
# Out:
# 7.0

# %%
pop_data[pop_data['Population'] == pop_data.Population.max()]
# Out:
#         Country   City AccentCity Region  Population  Latitude   Longitude
# 1544449      jp  tokyo      Tokyo     40  31480498.0    35.685  139.751389

# %%
pop_data[pop_data['Population'] == pop_data.Population.min()]
# Out:
#         Country        City  AccentCity Region  Population   Latitude  \
# 1028303      gl    neriunaq    Neriunaq     03         7.0  64.466667
# 1028477      gl    tasiusaq    Tasiusaq     03         7.0  73.366667
# 1028486      gl   timerliit   Timerliit     03         7.0  65.833333
# 2360929      ru  aliskerovo  Aliskerovo     15         7.0  67.766667
#
#           Longitude
# 1028303  -50.316667
# 1028477  -56.050000
# 1028486  -53.250000
# 2360929  167.583333

# %%
pop_data.dtypes
# Out:
# Country        object
# City           object
# AccentCity     object
# Region         object
# Population    float64
# Latitude      float64
# Longitude     float64
# dtype: object

# %%
pop_usa = pop_data.query('Country == ["us"]')

# %%
pop_usa.head()
# Out:
#         Country            City      AccentCity Region  Population   Latitude  \
# 2907755      us       alabaster       Alabaster     AL     26738.0  33.244167
# 2907759      us     albertville     Albertville     AL     18368.0  34.267500
# 2907765      us  alexander city  Alexander City     AL     14993.0  32.943889
# 2907804      us        anniston        Anniston     AL     23423.0  33.659722
# 2907848      us          athens          Athens     AL     20470.0  34.802778
#
#          Longitude
# 2907755 -86.816389
# 2907759 -86.208889
# 2907765 -85.953889
# 2907804 -85.831667
# 2907848 -86.971667

# %%
pop_usa.shape
# Out:
# (4175, 7)

# %%
pop_usa.Population.min()
# Out:
# 216.0

# %%
pop_usa.Population.max()
# Out:
# 8107916.0

# %%
pop_canada = pop_data.query('Country == ["ca"]')

# %%
pop_canada.head(50)
# Out:
#        Country             City       AccentCity Region  Population  \
# 346347      ca       abbotsford       Abbotsford      2    151685.0
# 346357      ca            acton            Acton      8      8204.0
# 346358      ca       acton vale       Acton Vale     10      5135.0
# 346369      ca          airdrie          Airdrie      1     24673.0
# 346374      ca          aklavik          Aklavik     13       648.0
# 346377      ca          albanel          Albanel     10      1087.0
# 346384      ca         alberton         Alberton      9      1147.0
# 346389      ca       aldergrove       Aldergrove      2     11963.0
# 346398      ca       alexandria       Alexandria      8      3559.0
# 346402      ca           alfred           Alfred      8      1424.0
# 346414      ca         alliston         Alliston      8     10224.0
# 346417      ca             alma             Alma     10     29527.0
# 346419      ca          almonte          Almonte      8      4921.0
# ...
